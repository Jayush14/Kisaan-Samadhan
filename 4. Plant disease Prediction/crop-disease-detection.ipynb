# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
       # print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121

# %%
disease_types = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
data_dir = '../input/plantdisease/PlantVillage/'
train_dir = os.path.join(data_dir)
#test_dir = os.path.join(data_dir, 'test')

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.tail()
# Out:
#                                                     File  DiseaseID  \
# 20634  Tomato_healthy/0ed55b5a-55e6-4c9c-bce4-9eba61b...         14
# 20635  Tomato_healthy/29289230-4809-46cd-ba98-77af06a...         14
# 20636  Tomato_healthy/2d66100e-9a61-412b-95da-2b852de...         14
# 20637  Tomato_healthy/0d615a38-cfa4-45e4-b1b4-9977220...         14
# 20638  Tomato_healthy/bb8861fc-350e-49da-86aa-1b475a2...         14
#
#          Disease Type
# 20634  Tomato_healthy
# 20635  Tomato_healthy
# 20636  Tomato_healthy
# 20637  Tomato_healthy
# 20638  Tomato_healthy

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                                                 File  DiseaseID  \
# 0  Tomato_healthy/4f256237-9e94-4703-b128-8e91ffa...         14
# 1  Potato___Early_blight/f917c191-cca4-4a78-8238-...          2
# 2  Tomato_Septoria_leaf_spot/1c721799-1ac2-47dd-8...          9
# 3  Tomato_healthy/4ed59995-6214-4996-b98b-750e854...         14
# 4  Tomato_Leaf_Mold/333654c3-6429-4ac2-b648-23b80...          8
#
#                 Disease Type
# 0             Tomato_healthy
# 1      Potato___Early_blight
# 2  Tomato_Septoria_leaf_spot
# 3             Tomato_healthy
# 4           Tomato_Leaf_Mold

# %%
# Plot a histogram
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
# Display images for different species
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('Tomato_Bacterial_spot', 5, 5)

# %%
IMAGE_SIZE = 64

def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 20639it [02:02, 168.22it/s]
# Train Shape: (20639, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=15)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 900
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(15,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 1s 0us/step
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 15)                3855
# =================================================================
# Total params: 7,308,963
# Trainable params: 7,222,755
# Non-trainable params: 86,208
# _________________________________________________________________
# Epoch 1/900
#
# Epoch 00001: val_loss improved from inf to 5.08875, saving model to model.h5
# 257/257 - 37s - loss: 2.6916 - accuracy: 0.2951 - val_loss: 5.0888 - val_accuracy: 0.1541
# Epoch 2/900
#
# Epoch 00002: val_loss improved from 5.08875 to 1.74963, saving model to model.h5
# 257/257 - 32s - loss: 1.2104 - accuracy: 0.6241 - val_loss: 1.7496 - val_accuracy: 0.5036
# Epoch 3/900
#
# Epoch 00003: val_loss improved from 1.74963 to 0.79154, saving model to model.h5
# 257/257 - 34s - loss: 0.6994 - accuracy: 0.7740 - val_loss: 0.7915 - val_accuracy: 0.7602
# Epoch 4/900
#
# Epoch 00004: val_loss improved from 0.79154 to 0.53497, saving model to model.h5
# 257/257 - 33s - loss: 0.4972 - accuracy: 0.8394 - val_loss: 0.5350 - val_accuracy: 0.8384
# Epoch 5/900
#
# Epoch 00005: val_loss did not improve from 0.53497
# 257/257 - 32s - loss: 0.3725 - accuracy: 0.8774 - val_loss: 1.2076 - val_accuracy: 0.7086
# Epoch 6/900
#
# Epoch 00006: val_loss improved from 0.53497 to 0.43429, saving model to model.h5
# 257/257 - 35s - loss: 0.3102 - accuracy: 0.9001 - val_loss: 0.4343 - val_accuracy: 0.8716
# Epoch 7/900
#
# Epoch 00007: val_loss did not improve from 0.43429
# 257/257 - 32s - loss: 0.2714 - accuracy: 0.9132 - val_loss: 0.6676 - val_accuracy: 0.7994
# Epoch 8/900
#
# Epoch 00008: val_loss improved from 0.43429 to 0.40435, saving model to model.h5
# 257/257 - 35s - loss: 0.2459 - accuracy: 0.9205 - val_loss: 0.4044 - val_accuracy: 0.8881
# Epoch 9/900
#
# Epoch 00009: val_loss improved from 0.40435 to 0.26755, saving model to model.h5
# 257/257 - 32s - loss: 0.2198 - accuracy: 0.9292 - val_loss: 0.2676 - val_accuracy: 0.9065
# Epoch 10/900
#
# Epoch 00010: val_loss did not improve from 0.26755
# 257/257 - 32s - loss: 0.2010 - accuracy: 0.9367 - val_loss: 0.8794 - val_accuracy: 0.7769
# Epoch 11/900
#
# Epoch 00011: val_loss did not improve from 0.26755
# 257/257 - 31s - loss: 0.1857 - accuracy: 0.9412 - val_loss: 0.4572 - val_accuracy: 0.8835
# Epoch 12/900
#
# Epoch 00012: val_loss did not improve from 0.26755
# 257/257 - 32s - loss: 0.1726 - accuracy: 0.9458 - val_loss: 0.3580 - val_accuracy: 0.8898
# Epoch 13/900
#
# Epoch 00013: val_loss did not improve from 0.26755
# 257/257 - 31s - loss: 0.1478 - accuracy: 0.9512 - val_loss: 0.3832 - val_accuracy: 0.8929
# Epoch 14/900
#
# Epoch 00014: val_loss improved from 0.26755 to 0.22045, saving model to model.h5
# 257/257 - 34s - loss: 0.1434 - accuracy: 0.9537 - val_loss: 0.2205 - val_accuracy: 0.9283
# Epoch 15/900
#
# Epoch 00015: val_loss improved from 0.22045 to 0.18037, saving model to model.h5
# 257/257 - 33s - loss: 0.1305 - accuracy: 0.9587 - val_loss: 0.1804 - val_accuracy: 0.9397
# Epoch 16/900
#
# Epoch 00016: val_loss did not improve from 0.18037
# 257/257 - 31s - loss: 0.1283 - accuracy: 0.9590 - val_loss: 0.7826 - val_accuracy: 0.7907
# Epoch 17/900
#
# Epoch 00017: val_loss did not improve from 0.18037
# 257/257 - 32s - loss: 0.1206 - accuracy: 0.9617 - val_loss: 0.4222 - val_accuracy: 0.8801
# Epoch 18/900
#
# Epoch 00018: val_loss did not improve from 0.18037
# 257/257 - 31s - loss: 0.1084 - accuracy: 0.9647 - val_loss: 0.3012 - val_accuracy: 0.9133
# Epoch 19/900
#
# Epoch 00019: val_loss did not improve from 0.18037
# 257/257 - 32s - loss: 0.1049 - accuracy: 0.9649 - val_loss: 0.1930 - val_accuracy: 0.9423
# Epoch 20/900
#
# Epoch 00020: val_loss did not improve from 0.18037
# 257/257 - 31s - loss: 0.0970 - accuracy: 0.9683 - val_loss: 1.7982 - val_accuracy: 0.6732
# Epoch 21/900
#
# Epoch 00021: val_loss did not improve from 0.18037
# 257/257 - 32s - loss: 0.0918 - accuracy: 0.9712 - val_loss: 0.8099 - val_accuracy: 0.8043
# Epoch 22/900
#
# Epoch 00022: val_loss did not improve from 0.18037
# 257/257 - 31s - loss: 0.0891 - accuracy: 0.9714 - val_loss: 0.2521 - val_accuracy: 0.9278
# Epoch 23/900
#
# Epoch 00023: val_loss did not improve from 0.18037
# 257/257 - 32s - loss: 0.0838 - accuracy: 0.9726 - val_loss: 0.3292 - val_accuracy: 0.9082
# Epoch 24/900
#
# Epoch 00024: val_loss improved from 0.18037 to 0.12521, saving model to model.h5
# 257/257 - 33s - loss: 0.0839 - accuracy: 0.9734 - val_loss: 0.1252 - val_accuracy: 0.9586
# Epoch 25/900
#
# Epoch 00025: val_loss did not improve from 0.12521
# 257/257 - 32s - loss: 0.0737 - accuracy: 0.9765 - val_loss: 0.3715 - val_accuracy: 0.8966
# Epoch 26/900
#
# Epoch 00026: val_loss did not improve from 0.12521
# 257/257 - 32s - loss: 0.0723 - accuracy: 0.9778 - val_loss: 1.4795 - val_accuracy: 0.6696
# Epoch 27/900
#
# Epoch 00027: val_loss did not improve from 0.12521
# 257/257 - 32s - loss: 0.0740 - accuracy: 0.9760 - val_loss: 0.3710 - val_accuracy: 0.9072
# Epoch 28/900
#
# Epoch 00028: val_loss did not improve from 0.12521
# 257/257 - 31s - loss: 0.0679 - accuracy: 0.9790 - val_loss: 0.2762 - val_accuracy: 0.9271
# Epoch 29/900
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 00029: val_loss did not improve from 0.12521
# 257/257 - 31s - loss: 0.0639 - accuracy: 0.9799 - val_loss: 0.6809 - val_accuracy: 0.8467
# Epoch 30/900
#
# Epoch 00030: val_loss improved from 0.12521 to 0.09064, saving model to model.h5
# 257/257 - 33s - loss: 0.0524 - accuracy: 0.9821 - val_loss: 0.0906 - val_accuracy: 0.9724
# Epoch 31/900
#
# Epoch 00031: val_loss did not improve from 0.09064
# 257/257 - 30s - loss: 0.0485 - accuracy: 0.9839 - val_loss: 0.1235 - val_accuracy: 0.9629
# Epoch 32/900
#
# Epoch 00032: val_loss did not improve from 0.09064
# 257/257 - 31s - loss: 0.0416 - accuracy: 0.9866 - val_loss: 0.1493 - val_accuracy: 0.9571
# Epoch 33/900
#
# Epoch 00033: val_loss improved from 0.09064 to 0.07576, saving model to model.h5
# 257/257 - 31s - loss: 0.0497 - accuracy: 0.9841 - val_loss: 0.0758 - val_accuracy: 0.9750
# Epoch 34/900
#
# Epoch 00034: val_loss improved from 0.07576 to 0.05004, saving model to model.h5
# 257/257 - 32s - loss: 0.0421 - accuracy: 0.9860 - val_loss: 0.0500 - val_accuracy: 0.9843
# Epoch 35/900
#
# Epoch 00035: val_loss did not improve from 0.05004
# 257/257 - 28s - loss: 0.0419 - accuracy: 0.9862 - val_loss: 0.0919 - val_accuracy: 0.9721
# Epoch 36/900
#
# Epoch 00036: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0385 - accuracy: 0.9881 - val_loss: 0.0826 - val_accuracy: 0.9741
# Epoch 37/900
#
# Epoch 00037: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0394 - accuracy: 0.9875 - val_loss: 0.0634 - val_accuracy: 0.9797
# Epoch 38/900
#
# Epoch 00038: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0444 - accuracy: 0.9866 - val_loss: 0.1591 - val_accuracy: 0.9525
# Epoch 39/900
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00039: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0352 - accuracy: 0.9885 - val_loss: 0.2437 - val_accuracy: 0.9327
# Epoch 40/900
#
# Epoch 00040: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0348 - accuracy: 0.9885 - val_loss: 0.2355 - val_accuracy: 0.9324
# Epoch 41/900
#
# Epoch 00041: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0350 - accuracy: 0.9892 - val_loss: 0.1300 - val_accuracy: 0.9656
# Epoch 42/900
#
# Epoch 00042: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0344 - accuracy: 0.9891 - val_loss: 0.0770 - val_accuracy: 0.9767
# Epoch 43/900
#
# Epoch 00043: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0361 - accuracy: 0.9884 - val_loss: 0.0657 - val_accuracy: 0.9784
# Epoch 44/900
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00044: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0312 - accuracy: 0.9897 - val_loss: 0.2611 - val_accuracy: 0.9334
# Epoch 45/900
#
# Epoch 00045: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0348 - accuracy: 0.9881 - val_loss: 0.1115 - val_accuracy: 0.9683
# Epoch 46/900
#
# Epoch 00046: val_loss did not improve from 0.05004
# 257/257 - 28s - loss: 0.0310 - accuracy: 0.9908 - val_loss: 0.0927 - val_accuracy: 0.9717
# Epoch 47/900
#
# Epoch 00047: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0324 - accuracy: 0.9894 - val_loss: 0.2094 - val_accuracy: 0.9365
# Epoch 48/900
#
# Epoch 00048: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0331 - accuracy: 0.9889 - val_loss: 0.0558 - val_accuracy: 0.9813
# Epoch 49/900
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00049: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0309 - accuracy: 0.9905 - val_loss: 0.1067 - val_accuracy: 0.9671
# Epoch 50/900
#
# Epoch 00050: val_loss did not improve from 0.05004
# 257/257 - 31s - loss: 0.0337 - accuracy: 0.9894 - val_loss: 0.1312 - val_accuracy: 0.9622
# Epoch 51/900
#
# Epoch 00051: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0289 - accuracy: 0.9912 - val_loss: 0.8274 - val_accuracy: 0.8072
# Epoch 52/900
#
# Epoch 00052: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0269 - accuracy: 0.9923 - val_loss: 0.7147 - val_accuracy: 0.8324
# Epoch 53/900
#
# Epoch 00053: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0287 - accuracy: 0.9912 - val_loss: 0.0753 - val_accuracy: 0.9729
# Epoch 54/900
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00054: val_loss did not improve from 0.05004
# 257/257 - 28s - loss: 0.0289 - accuracy: 0.9906 - val_loss: 0.1202 - val_accuracy: 0.9666
# Epoch 55/900
#
# Epoch 00055: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0305 - accuracy: 0.9903 - val_loss: 0.2231 - val_accuracy: 0.9414
# Epoch 56/900
#
# Epoch 00056: val_loss did not improve from 0.05004
# 257/257 - 28s - loss: 0.0272 - accuracy: 0.9915 - val_loss: 0.4653 - val_accuracy: 0.8881
# Epoch 57/900
#
# Epoch 00057: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0263 - accuracy: 0.9922 - val_loss: 0.1445 - val_accuracy: 0.9564
# Epoch 58/900
#
# Epoch 00058: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0264 - accuracy: 0.9919 - val_loss: 0.2794 - val_accuracy: 0.9317
# Epoch 59/900
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00059: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0293 - accuracy: 0.9907 - val_loss: 0.0543 - val_accuracy: 0.9828
# Epoch 60/900
#
# Epoch 00060: val_loss did not improve from 0.05004
# 257/257 - 28s - loss: 0.0264 - accuracy: 0.9918 - val_loss: 0.8636 - val_accuracy: 0.8064
# Epoch 61/900
#
# Epoch 00061: val_loss did not improve from 0.05004
# 257/257 - 30s - loss: 0.0214 - accuracy: 0.9929 - val_loss: 0.1121 - val_accuracy: 0.9692
# Epoch 62/900
#
# Epoch 00062: val_loss did not improve from 0.05004
# 257/257 - 28s - loss: 0.0244 - accuracy: 0.9926 - val_loss: 0.0566 - val_accuracy: 0.9806
# Epoch 63/900
#
# Epoch 00063: val_loss did not improve from 0.05004
# 257/257 - 29s - loss: 0.0252 - accuracy: 0.9913 - val_loss: 0.0739 - val_accuracy: 0.9780
# Epoch 64/900
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00064: val_loss did not improve from 0.05004
# 257/257 - 27s - loss: 0.0253 - accuracy: 0.9928 - val_loss: 0.7028 - val_accuracy: 0.8430
# Epoch 65/900
#
# Epoch 00065: val_loss improved from 0.05004 to 0.04965, saving model to model.h5
# 257/257 - 30s - loss: 0.0222 - accuracy: 0.9936 - val_loss: 0.0497 - val_accuracy: 0.9857
# Epoch 66/900
#
# Epoch 00066: val_loss did not improve from 0.04965
# 257/257 - 28s - loss: 0.0231 - accuracy: 0.9935 - val_loss: 0.3441 - val_accuracy: 0.9198
# Epoch 67/900
#
# Epoch 00067: val_loss did not improve from 0.04965
# 257/257 - 29s - loss: 0.0222 - accuracy: 0.9935 - val_loss: 0.1212 - val_accuracy: 0.9646
# Epoch 68/900
#
# Epoch 00068: val_loss did not improve from 0.04965
# 257/257 - 27s - loss: 0.0252 - accuracy: 0.9917 - val_loss: 0.0900 - val_accuracy: 0.9726
# Epoch 69/900
#
# Epoch 00069: val_loss did not improve from 0.04965
# 257/257 - 30s - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.0586 - val_accuracy: 0.9818
# Epoch 70/900
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00070: val_loss did not improve from 0.04965
# 257/257 - 27s - loss: 0.0261 - accuracy: 0.9922 - val_loss: 0.3454 - val_accuracy: 0.9128
# Epoch 71/900
#
# Epoch 00071: val_loss did not improve from 0.04965
# 257/257 - 29s - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.2417 - val_accuracy: 0.9426
# Epoch 72/900
#
# Epoch 00072: val_loss did not improve from 0.04965
# 257/257 - 28s - loss: 0.0230 - accuracy: 0.9931 - val_loss: 0.0501 - val_accuracy: 0.9852
# Epoch 73/900
#
# Epoch 00073: val_loss did not improve from 0.04965
# 257/257 - 28s - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.1862 - val_accuracy: 0.9491
# Epoch 74/900
#
# Epoch 00074: val_loss did not improve from 0.04965
# 257/257 - 27s - loss: 0.0231 - accuracy: 0.9930 - val_loss: 0.1756 - val_accuracy: 0.9559
# Epoch 75/900
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00075: val_loss did not improve from 0.04965
# 257/257 - 28s - loss: 0.0223 - accuracy: 0.9935 - val_loss: 0.0571 - val_accuracy: 0.9799
# Epoch 76/900
#
# Epoch 00076: val_loss did not improve from 0.04965
# 257/257 - 28s - loss: 0.0210 - accuracy: 0.9939 - val_loss: 0.0656 - val_accuracy: 0.9775
# Epoch 77/900
#
# Epoch 00077: val_loss improved from 0.04965 to 0.04896, saving model to model.h5
# 257/257 - 29s - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.0490 - val_accuracy: 0.9852
# Epoch 78/900
#
# Epoch 00078: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0189 - accuracy: 0.9930 - val_loss: 0.0652 - val_accuracy: 0.9767
# Epoch 79/900
#
# Epoch 00079: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.0694 - val_accuracy: 0.9813
# Epoch 80/900
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00080: val_loss did not improve from 0.04896
# 257/257 - 29s - loss: 0.0222 - accuracy: 0.9930 - val_loss: 0.1276 - val_accuracy: 0.9671
# Epoch 81/900
#
# Epoch 00081: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0189 - accuracy: 0.9938 - val_loss: 0.0611 - val_accuracy: 0.9813
# Epoch 82/900
#
# Epoch 00082: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.2921 - val_accuracy: 0.9266
# Epoch 83/900
#
# Epoch 00083: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.1205 - val_accuracy: 0.9683
# Epoch 84/900
#
# Epoch 00084: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0191 - accuracy: 0.9943 - val_loss: 0.2334 - val_accuracy: 0.9377
# Epoch 85/900
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00085: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0205 - accuracy: 0.9937 - val_loss: 0.0914 - val_accuracy: 0.9717
# Epoch 86/900
#
# Epoch 00086: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0232 - accuracy: 0.9936 - val_loss: 0.5159 - val_accuracy: 0.8837
# Epoch 87/900
#
# Epoch 00087: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0217 - accuracy: 0.9940 - val_loss: 0.0627 - val_accuracy: 0.9806
# Epoch 88/900
#
# Epoch 00088: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0210 - accuracy: 0.9940 - val_loss: 0.3005 - val_accuracy: 0.9271
# Epoch 89/900
#
# Epoch 00089: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.7496 - val_accuracy: 0.8394
# Epoch 90/900
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00090: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.0533 - val_accuracy: 0.9840
# Epoch 91/900
#
# Epoch 00091: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0693 - val_accuracy: 0.9772
# Epoch 92/900
#
# Epoch 00092: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0205 - accuracy: 0.9940 - val_loss: 0.0524 - val_accuracy: 0.9852
# Epoch 93/900
#
# Epoch 00093: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.0904 - val_accuracy: 0.9724
# Epoch 94/900
#
# Epoch 00094: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0162 - accuracy: 0.9951 - val_loss: 0.1080 - val_accuracy: 0.9697
# Epoch 95/900
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00095: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0176 - accuracy: 0.9948 - val_loss: 0.1066 - val_accuracy: 0.9688
# Epoch 96/900
#
# Epoch 00096: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.1097 - val_accuracy: 0.9692
# Epoch 97/900
#
# Epoch 00097: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0154 - accuracy: 0.9951 - val_loss: 0.0996 - val_accuracy: 0.9692
# Epoch 98/900
#
# Epoch 00098: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0172 - accuracy: 0.9946 - val_loss: 0.4963 - val_accuracy: 0.8987
# Epoch 99/900
#
# Epoch 00099: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.1419 - val_accuracy: 0.9622
# Epoch 100/900
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00100: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.0730 - val_accuracy: 0.9780
# Epoch 101/900
#
# Epoch 00101: val_loss did not improve from 0.04896
# 257/257 - 30s - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.0836 - val_accuracy: 0.9750
# Epoch 102/900
#
# Epoch 00102: val_loss did not improve from 0.04896
# 257/257 - 27s - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.2515 - val_accuracy: 0.9351
# Epoch 103/900
#
# Epoch 00103: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0168 - accuracy: 0.9943 - val_loss: 0.0754 - val_accuracy: 0.9789
# Epoch 104/900
#
# Epoch 00104: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.2164 - val_accuracy: 0.9479
# Epoch 105/900
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00105: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.2292 - val_accuracy: 0.9426
# Epoch 106/900
#
# Epoch 00106: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.7412 - val_accuracy: 0.8672
# Epoch 107/900
#
# Epoch 00107: val_loss did not improve from 0.04896
# 257/257 - 28s - loss: 0.0190 - accuracy: 0.9945 - val_loss: 0.9246 - val_accuracy: 0.8094
# Epoch 108/900
#
# Epoch 00108: val_loss improved from 0.04896 to 0.04056, saving model to model.h5
# 257/257 - 30s - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.0406 - val_accuracy: 0.9879
# Epoch 109/900
#
# Epoch 00109: val_loss did not improve from 0.04056
# 257/257 - 27s - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.0421 - val_accuracy: 0.9869
# Epoch 110/900
#
# Epoch 00110: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0545 - val_accuracy: 0.9838
# Epoch 111/900
#
# Epoch 00111: val_loss did not improve from 0.04056
# 257/257 - 27s - loss: 0.0132 - accuracy: 0.9957 - val_loss: 0.0455 - val_accuracy: 0.9862
# Epoch 112/900
#
# Epoch 00112: val_loss did not improve from 0.04056
# 257/257 - 29s - loss: 0.0154 - accuracy: 0.9954 - val_loss: 0.0489 - val_accuracy: 0.9862
# Epoch 113/900
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00113: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.5882 - val_accuracy: 0.8687
# Epoch 114/900
#
# Epoch 00114: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0671 - val_accuracy: 0.9804
# Epoch 115/900
#
# Epoch 00115: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0154 - accuracy: 0.9954 - val_loss: 0.2224 - val_accuracy: 0.9443
# Epoch 116/900
#
# Epoch 00116: val_loss did not improve from 0.04056
# 257/257 - 29s - loss: 0.0165 - accuracy: 0.9945 - val_loss: 0.0763 - val_accuracy: 0.9782
# Epoch 117/900
#
# Epoch 00117: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.0955 - val_accuracy: 0.9734
# Epoch 118/900
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00118: val_loss did not improve from 0.04056
# 257/257 - 29s - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.1460 - val_accuracy: 0.9608
# Epoch 119/900
#
# Epoch 00119: val_loss did not improve from 0.04056
# 257/257 - 27s - loss: 0.0157 - accuracy: 0.9947 - val_loss: 0.3741 - val_accuracy: 0.9118
# Epoch 120/900
#
# Epoch 00120: val_loss did not improve from 0.04056
# 257/257 - 29s - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.2300 - val_accuracy: 0.9455
# Epoch 121/900
#
# Epoch 00121: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0156 - accuracy: 0.9946 - val_loss: 0.0535 - val_accuracy: 0.9857
# Epoch 122/900
#
# Epoch 00122: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.0485 - val_accuracy: 0.9855
# Epoch 123/900
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00123: val_loss did not improve from 0.04056
# 257/257 - 27s - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.1247 - val_accuracy: 0.9646
# Epoch 124/900
#
# Epoch 00124: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.1558 - val_accuracy: 0.9583
# Epoch 125/900
#
# Epoch 00125: val_loss did not improve from 0.04056
# 257/257 - 28s - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.2686 - val_accuracy: 0.9426
# Epoch 126/900
#
# Epoch 00126: val_loss did not improve from 0.04056
# 257/257 - 29s - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0720 - val_accuracy: 0.9792
# Epoch 127/900
#
# Epoch 00127: val_loss did not improve from 0.04056
# 257/257 - 29s - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.6638 - val_accuracy: 0.8542
# Epoch 128/900
#
# Epoch 00128: val_loss improved from 0.04056 to 0.03550, saving model to model.h5
# 257/257 - 30s - loss: 0.0114 - accuracy: 0.9967 - val_loss: 0.0355 - val_accuracy: 0.9893
# Epoch 129/900
#
# Epoch 00129: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0394 - val_accuracy: 0.9874
# Epoch 130/900
#
# Epoch 00130: val_loss did not improve from 0.03550
# 257/257 - 28s - loss: 0.0141 - accuracy: 0.9962 - val_loss: 0.0596 - val_accuracy: 0.9811
# Epoch 131/900
#
# Epoch 00131: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.4863 - val_accuracy: 0.8949
# Epoch 132/900
#
# Epoch 00132: val_loss did not improve from 0.03550
# 257/257 - 28s - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0928 - val_accuracy: 0.9755
# Epoch 133/900
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00133: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.2321 - val_accuracy: 0.9436
# Epoch 134/900
#
# Epoch 00134: val_loss did not improve from 0.03550
# 257/257 - 27s - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.3238 - val_accuracy: 0.9268
# Epoch 135/900
#
# Epoch 00135: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0464 - val_accuracy: 0.9855
# Epoch 136/900
#
# Epoch 00136: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0117 - accuracy: 0.9968 - val_loss: 0.0832 - val_accuracy: 0.9770
# Epoch 137/900
#
# Epoch 00137: val_loss did not improve from 0.03550
# 257/257 - 33s - loss: 0.0152 - accuracy: 0.9956 - val_loss: 0.0529 - val_accuracy: 0.9850
# Epoch 138/900
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00138: val_loss did not improve from 0.03550
# 257/257 - 31s - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.5036 - val_accuracy: 0.8883
# Epoch 139/900
#
# Epoch 00139: val_loss did not improve from 0.03550
# 257/257 - 33s - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.1603 - val_accuracy: 0.9566
# Epoch 140/900
#
# Epoch 00140: val_loss did not improve from 0.03550
# 257/257 - 31s - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.1453 - val_accuracy: 0.9634
# Epoch 141/900
#
# Epoch 00141: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0120 - accuracy: 0.9959 - val_loss: 1.3606 - val_accuracy: 0.7594
# Epoch 142/900
#
# Epoch 00142: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0120 - accuracy: 0.9959 - val_loss: 0.0415 - val_accuracy: 0.9859
# Epoch 143/900
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00143: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.3977 - val_accuracy: 0.9099
# Epoch 144/900
#
# Epoch 00144: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0823 - val_accuracy: 0.9753
# Epoch 145/900
#
# Epoch 00145: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.1905 - val_accuracy: 0.9554
# Epoch 146/900
#
# Epoch 00146: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0137 - accuracy: 0.9959 - val_loss: 0.0682 - val_accuracy: 0.9809
# Epoch 147/900
#
# Epoch 00147: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0829 - val_accuracy: 0.9760
# Epoch 148/900
#
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00148: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.1687 - val_accuracy: 0.9588
# Epoch 149/900
#
# Epoch 00149: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.0633 - val_accuracy: 0.9813
# Epoch 150/900
#
# Epoch 00150: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0124 - accuracy: 0.9967 - val_loss: 0.4092 - val_accuracy: 0.9070
# Epoch 151/900
#
# Epoch 00151: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0468 - val_accuracy: 0.9862
# Epoch 152/900
#
# Epoch 00152: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.1525 - val_accuracy: 0.9610
# Epoch 153/900
#
# Epoch 00153: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00153: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0798 - val_accuracy: 0.9767
# Epoch 154/900
#
# Epoch 00154: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1767 - val_accuracy: 0.9566
# Epoch 155/900
#
# Epoch 00155: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.0700 - val_accuracy: 0.9821
# Epoch 156/900
#
# Epoch 00156: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.2118 - val_accuracy: 0.9508
# Epoch 157/900
#
# Epoch 00157: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0883 - val_accuracy: 0.9748
# Epoch 158/900
#
# Epoch 00158: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00158: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0799 - val_accuracy: 0.9792
# Epoch 159/900
#
# Epoch 00159: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.1342 - val_accuracy: 0.9666
# Epoch 160/900
#
# Epoch 00160: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.0797 - val_accuracy: 0.9770
# Epoch 161/900
#
# Epoch 00161: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.0619 - val_accuracy: 0.9833
# Epoch 162/900
#
# Epoch 00162: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.6513 - val_accuracy: 0.8687
# Epoch 163/900
#
# Epoch 00163: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00163: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.0823 - val_accuracy: 0.9741
# Epoch 164/900
#
# Epoch 00164: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.1200 - val_accuracy: 0.9690
# Epoch 165/900
#
# Epoch 00165: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.2911 - val_accuracy: 0.9346
# Epoch 166/900
#
# Epoch 00166: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.1956 - val_accuracy: 0.9542
# Epoch 167/900
#
# Epoch 00167: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0100 - accuracy: 0.9972 - val_loss: 0.0598 - val_accuracy: 0.9833
# Epoch 168/900
#
# Epoch 00168: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00168: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0107 - accuracy: 0.9974 - val_loss: 0.0414 - val_accuracy: 0.9869
# Epoch 169/900
#
# Epoch 00169: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0084 - accuracy: 0.9976 - val_loss: 0.0406 - val_accuracy: 0.9881
# Epoch 170/900
#
# Epoch 00170: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.1562 - val_accuracy: 0.9615
# Epoch 171/900
#
# Epoch 00171: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.0625 - val_accuracy: 0.9828
# Epoch 172/900
#
# Epoch 00172: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.1940 - val_accuracy: 0.9535
# Epoch 173/900
#
# Epoch 00173: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00173: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0972 - val_accuracy: 0.9760
# Epoch 174/900
#
# Epoch 00174: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.1582 - val_accuracy: 0.9617
# Epoch 175/900
#
# Epoch 00175: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.2167 - val_accuracy: 0.9506
# Epoch 176/900
#
# Epoch 00176: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.0487 - val_accuracy: 0.9886
# Epoch 177/900
#
# Epoch 00177: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.2154 - val_accuracy: 0.9518
# Epoch 178/900
#
# Epoch 00178: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00178: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0446 - val_accuracy: 0.9874
# Epoch 179/900
#
# Epoch 00179: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.1996 - val_accuracy: 0.9513
# Epoch 180/900
#
# Epoch 00180: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.5906 - val_accuracy: 0.8794
# Epoch 181/900
#
# Epoch 00181: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.2379 - val_accuracy: 0.9457
# Epoch 182/900
#
# Epoch 00182: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.2635 - val_accuracy: 0.9436
# Epoch 183/900
#
# Epoch 00183: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00183: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0891 - val_accuracy: 0.9738
# Epoch 184/900
#
# Epoch 00184: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0412 - val_accuracy: 0.9903
# Epoch 185/900
#
# Epoch 00185: val_loss did not improve from 0.03550
# 257/257 - 31s - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.1427 - val_accuracy: 0.9637
# Epoch 186/900
#
# Epoch 00186: val_loss did not improve from 0.03550
# 257/257 - 32s - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.0563 - val_accuracy: 0.9840
# Epoch 187/900
#
# Epoch 00187: val_loss did not improve from 0.03550
# 257/257 - 32s - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.4213 - val_accuracy: 0.9123
# Epoch 188/900
#
# Epoch 00188: val_loss did not improve from 0.03550
# 257/257 - 31s - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.0397 - val_accuracy: 0.9889
# Epoch 189/900
#
# Epoch 00189: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00189: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0493 - val_accuracy: 0.9855
# Epoch 190/900
#
# Epoch 00190: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.1352 - val_accuracy: 0.9675
# Epoch 191/900
#
# Epoch 00191: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.5156 - val_accuracy: 0.8876
# Epoch 192/900
#
# Epoch 00192: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0471 - val_accuracy: 0.9867
# Epoch 193/900
#
# Epoch 00193: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.3622 - val_accuracy: 0.9259
# Epoch 194/900
#
# Epoch 00194: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00194: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.1234 - val_accuracy: 0.9673
# Epoch 195/900
#
# Epoch 00195: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.2393 - val_accuracy: 0.9467
# Epoch 196/900
#
# Epoch 00196: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.1479 - val_accuracy: 0.9620
# Epoch 197/900
#
# Epoch 00197: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.2295 - val_accuracy: 0.9421
# Epoch 198/900
#
# Epoch 00198: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0490 - val_accuracy: 0.9845
# Epoch 199/900
#
# Epoch 00199: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00199: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.0975 - val_accuracy: 0.9734
# Epoch 200/900
#
# Epoch 00200: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0408 - val_accuracy: 0.9884
# Epoch 201/900
#
# Epoch 00201: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.0904 - val_accuracy: 0.9753
# Epoch 202/900
#
# Epoch 00202: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.0836 - val_accuracy: 0.9794
# Epoch 203/900
#
# Epoch 00203: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0574 - val_accuracy: 0.9845
# Epoch 204/900
#
# Epoch 00204: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00204: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.1225 - val_accuracy: 0.9709
# Epoch 205/900
#
# Epoch 00205: val_loss did not improve from 0.03550
# 257/257 - 28s - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0386 - val_accuracy: 0.9891
# Epoch 206/900
#
# Epoch 00206: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.1430 - val_accuracy: 0.9658
# Epoch 207/900
#
# Epoch 00207: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0719 - val_accuracy: 0.9809
# Epoch 208/900
#
# Epoch 00208: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.0472 - val_accuracy: 0.9852
# Epoch 209/900
#
# Epoch 00209: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00209: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0088 - accuracy: 0.9970 - val_loss: 1.8422 - val_accuracy: 0.6846
# Epoch 210/900
#
# Epoch 00210: val_loss did not improve from 0.03550
# 257/257 - 30s - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0978 - val_accuracy: 0.9721
# Epoch 211/900
#
# Epoch 00211: val_loss did not improve from 0.03550
# 257/257 - 29s - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.3587 - val_accuracy: 0.9213
# Epoch 212/900
#
# Epoch 00212: val_loss improved from 0.03550 to 0.02806, saving model to model.h5
# 257/257 - 31s - loss: 0.0102 - accuracy: 0.9971 - val_loss: 0.0281 - val_accuracy: 0.9922
# Epoch 213/900
#
# Epoch 00213: val_loss did not improve from 0.02806
# 257/257 - 31s - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.7139 - val_accuracy: 0.8597
# Epoch 214/900
#
# Epoch 00214: val_loss did not improve from 0.02806
# 257/257 - 33s - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0309 - val_accuracy: 0.9913
# Epoch 215/900
#
# Epoch 00215: val_loss did not improve from 0.02806
# 257/257 - 30s - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0698 - val_accuracy: 0.9772
# Epoch 216/900
#
# Epoch 00216: val_loss did not improve from 0.02806
# 257/257 - 31s - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0795 - val_accuracy: 0.9777
# Epoch 217/900
#
# Epoch 00217: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00217: val_loss did not improve from 0.02806
# 257/257 - 30s - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0381 - val_accuracy: 0.9896
# Epoch 218/900
#
# Epoch 00218: val_loss did not improve from 0.02806
# 257/257 - 30s - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.1331 - val_accuracy: 0.9671
# Epoch 219/900
#
# Epoch 00219: val_loss did not improve from 0.02806
# 257/257 - 30s - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.1084 - val_accuracy: 0.9726
# Epoch 220/900
#
# Epoch 00220: val_loss did not improve from 0.02806
# 257/257 - 31s - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.1481 - val_accuracy: 0.9649
# Epoch 221/900
#
# Epoch 00221: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.1251 - val_accuracy: 0.9702
# Epoch 222/900
#
# Epoch 00222: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00222: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.4089 - val_accuracy: 0.9213
# Epoch 223/900
#
# Epoch 00223: val_loss did not improve from 0.02806
# 257/257 - 28s - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.1895 - val_accuracy: 0.9549
# Epoch 224/900
#
# Epoch 00224: val_loss did not improve from 0.02806
# 257/257 - 30s - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.0691 - val_accuracy: 0.9801
# Epoch 225/900
#
# Epoch 00225: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.1149 - val_accuracy: 0.9697
# Epoch 226/900
#
# Epoch 00226: val_loss did not improve from 0.02806
# 257/257 - 30s - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0605 - val_accuracy: 0.9845
# Epoch 227/900
#
# Epoch 00227: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00227: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.2458 - val_accuracy: 0.9448
# Epoch 228/900
#
# Epoch 00228: val_loss did not improve from 0.02806
# 257/257 - 30s - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0817 - val_accuracy: 0.9777
# Epoch 229/900
#
# Epoch 00229: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0390 - val_accuracy: 0.9901
# Epoch 230/900
#
# Epoch 00230: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0517 - val_accuracy: 0.9862
# Epoch 231/900
#
# Epoch 00231: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0930 - val_accuracy: 0.9760
# Epoch 232/900
#
# Epoch 00232: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00232: val_loss did not improve from 0.02806
# 257/257 - 30s - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.3990 - val_accuracy: 0.9138
# Epoch 233/900
#
# Epoch 00233: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.6336 - val_accuracy: 0.8726
# Epoch 234/900
#
# Epoch 00234: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.0863 - val_accuracy: 0.9780
# Epoch 235/900
#
# Epoch 00235: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0496 - val_accuracy: 0.9874
# Epoch 236/900
#
# Epoch 00236: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0412 - val_accuracy: 0.9893
# Epoch 237/900
#
# Epoch 00237: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00237: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0821 - val_accuracy: 0.9780
# Epoch 238/900
#
# Epoch 00238: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0330 - val_accuracy: 0.9906
# Epoch 239/900
#
# Epoch 00239: val_loss did not improve from 0.02806
# 257/257 - 28s - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.1253 - val_accuracy: 0.9688
# Epoch 240/900
#
# Epoch 00240: val_loss did not improve from 0.02806
# 257/257 - 28s - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.0384 - val_accuracy: 0.9896
# Epoch 241/900
#
# Epoch 00241: val_loss did not improve from 0.02806
# 257/257 - 29s - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.1043 - val_accuracy: 0.9741
# Epoch 242/900
#
# Epoch 00242: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00242: val_loss did not improve from 0.02806
# 257/257 - 28s - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.1706 - val_accuracy: 0.9610
# Epoch 243/900
#
# Epoch 00243: val_loss improved from 0.02806 to 0.02735, saving model to model.h5
# 257/257 - 31s - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.0273 - val_accuracy: 0.9925
# Epoch 244/900
#
# Epoch 00244: val_loss did not improve from 0.02735
# 257/257 - 28s - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.3398 - val_accuracy: 0.9288
# Epoch 245/900
#
# Epoch 00245: val_loss improved from 0.02735 to 0.02680, saving model to model.h5
# 257/257 - 31s - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0268 - val_accuracy: 0.9935
# Epoch 246/900
#
# Epoch 00246: val_loss did not improve from 0.02680
# 257/257 - 27s - loss: 0.0080 - accuracy: 0.9982 - val_loss: 0.0600 - val_accuracy: 0.9835
# Epoch 247/900
#
# Epoch 00247: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.0897 - val_accuracy: 0.9748
# Epoch 248/900
#
# Epoch 00248: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.0354 - val_accuracy: 0.9886
# Epoch 249/900
#
# Epoch 00249: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0398 - val_accuracy: 0.9891
# Epoch 250/900
#
# Epoch 00250: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00250: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.2580 - val_accuracy: 0.9377
# Epoch 251/900
#
# Epoch 00251: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.1305 - val_accuracy: 0.9656
# Epoch 252/900
#
# Epoch 00252: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0284 - val_accuracy: 0.9927
# Epoch 253/900
#
# Epoch 00253: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0515 - val_accuracy: 0.9864
# Epoch 254/900
#
# Epoch 00254: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0321 - val_accuracy: 0.9922
# Epoch 255/900
#
# Epoch 00255: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00255: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0916 - val_accuracy: 0.9721
# Epoch 256/900
#
# Epoch 00256: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.1640 - val_accuracy: 0.9595
# Epoch 257/900
#
# Epoch 00257: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.2775 - val_accuracy: 0.9365
# Epoch 258/900
#
# Epoch 00258: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0344 - val_accuracy: 0.9896
# Epoch 259/900
#
# Epoch 00259: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0650 - val_accuracy: 0.9818
# Epoch 260/900
#
# Epoch 00260: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00260: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.1139 - val_accuracy: 0.9717
# Epoch 261/900
#
# Epoch 00261: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.1004 - val_accuracy: 0.9741
# Epoch 262/900
#
# Epoch 00262: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.0718 - val_accuracy: 0.9787
# Epoch 263/900
#
# Epoch 00263: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.0453 - val_accuracy: 0.9862
# Epoch 264/900
#
# Epoch 00264: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.1266 - val_accuracy: 0.9692
# Epoch 265/900
#
# Epoch 00265: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00265: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0420 - val_accuracy: 0.9881
# Epoch 266/900
#
# Epoch 00266: val_loss did not improve from 0.02680
# 257/257 - 27s - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0346 - val_accuracy: 0.9906
# Epoch 267/900
#
# Epoch 00267: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0768 - val_accuracy: 0.9770
# Epoch 268/900
#
# Epoch 00268: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0363 - val_accuracy: 0.9893
# Epoch 269/900
#
# Epoch 00269: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.1626 - val_accuracy: 0.9612
# Epoch 270/900
#
# Epoch 00270: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00270: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0605 - val_accuracy: 0.9845
# Epoch 271/900
#
# Epoch 00271: val_loss did not improve from 0.02680
# 257/257 - 28s - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.1024 - val_accuracy: 0.9717
# Epoch 272/900
#
# Epoch 00272: val_loss did not improve from 0.02680
# 257/257 - 29s - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.1888 - val_accuracy: 0.9598
# Epoch 273/900
#
# Epoch 00273: val_loss did not improve from 0.02680
# 257/257 - 27s - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0501 - val_accuracy: 0.9889
# Epoch 274/900
#
# Epoch 00274: val_loss did not improve from 0.02680
# ...
# Epoch 807/900
#
# Epoch 00807: val_loss did not improve from 0.02446
# 257/257 - 34s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0310 - val_accuracy: 0.9939
# Epoch 808/900
#
# Epoch 00808: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00808: val_loss did not improve from 0.02446
# 257/257 - 33s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.5078 - val_accuracy: 0.9111
# Epoch 809/900
#
# Epoch 00809: val_loss did not improve from 0.02446
# 257/257 - 33s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0666 - val_accuracy: 0.9818
# Epoch 810/900
#
# Epoch 00810: val_loss did not improve from 0.02446
# 257/257 - 34s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1026 - val_accuracy: 0.9772
# Epoch 811/900
#
# Epoch 00811: val_loss improved from 0.02446 to 0.02253, saving model to model.h5
# 257/257 - 34s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0225 - val_accuracy: 0.9949
# Epoch 812/900
#
# Epoch 00812: val_loss did not improve from 0.02253
# 257/257 - 33s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0544 - val_accuracy: 0.9889
# Epoch 813/900
#
# Epoch 00813: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00813: val_loss did not improve from 0.02253
# 257/257 - 33s - loss: 9.6859e-04 - accuracy: 0.9996 - val_loss: 0.0308 - val_accuracy: 0.9925
# Epoch 814/900
#
# Epoch 00814: val_loss did not improve from 0.02253
# 257/257 - 34s - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0399 - val_accuracy: 0.9906
# Epoch 815/900
#
# Epoch 00815: val_loss did not improve from 0.02253
# 257/257 - 33s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0327 - val_accuracy: 0.9918
# Epoch 816/900
#
# Epoch 00816: val_loss did not improve from 0.02253
# 257/257 - 33s - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.0639 - val_accuracy: 0.9838
# Epoch 817/900
#
# Epoch 00817: val_loss did not improve from 0.02253
# 257/257 - 34s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0373 - val_accuracy: 0.9910
# Epoch 818/900
#
# Epoch 00818: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00818: val_loss did not improve from 0.02253
# 257/257 - 32s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.3877 - val_accuracy: 0.9276
# Epoch 819/900
#
# Epoch 00819: val_loss did not improve from 0.02253
# 257/257 - 33s - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0511 - val_accuracy: 0.9884
# Epoch 820/900
#
# Epoch 00820: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.0509 - val_accuracy: 0.9891
# Epoch 821/900
#
# Epoch 00821: val_loss did not improve from 0.02253
# 257/257 - 32s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0318 - val_accuracy: 0.9925
# Epoch 822/900
#
# Epoch 00822: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0384 - val_accuracy: 0.9918
# Epoch 823/900
#
# Epoch 00823: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00823: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0343 - val_accuracy: 0.9918
# Epoch 824/900
#
# Epoch 00824: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0614 - val_accuracy: 0.9859
# Epoch 825/900
#
# Epoch 00825: val_loss did not improve from 0.02253
# 257/257 - 32s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0357 - val_accuracy: 0.9910
# Epoch 826/900
#
# Epoch 00826: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0506 - val_accuracy: 0.9884
# Epoch 827/900
#
# Epoch 00827: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0600 - val_accuracy: 0.9857
# Epoch 828/900
#
# Epoch 00828: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00828: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0933 - val_accuracy: 0.9792
# Epoch 829/900
#
# Epoch 00829: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0418 - val_accuracy: 0.9910
# Epoch 830/900
#
# Epoch 00830: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0516 - val_accuracy: 0.9893
# Epoch 831/900
#
# Epoch 00831: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0318 - val_accuracy: 0.9918
# Epoch 832/900
#
# Epoch 00832: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 6.7623e-04 - accuracy: 0.9998 - val_loss: 0.0383 - val_accuracy: 0.9920
# Epoch 833/900
#
# Epoch 00833: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00833: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0908 - val_accuracy: 0.9780
# Epoch 834/900
#
# Epoch 00834: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0871 - val_accuracy: 0.9813
# Epoch 835/900
#
# Epoch 00835: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0434 - val_accuracy: 0.9891
# Epoch 836/900
#
# Epoch 00836: val_loss did not improve from 0.02253
# 257/257 - 32s - loss: 9.2660e-04 - accuracy: 0.9996 - val_loss: 0.0389 - val_accuracy: 0.9910
# Epoch 837/900
#
# Epoch 00837: val_loss did not improve from 0.02253
# 257/257 - 32s - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0432 - val_accuracy: 0.9915
# Epoch 838/900
#
# Epoch 00838: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00838: val_loss did not improve from 0.02253
# 257/257 - 33s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1481 - val_accuracy: 0.9639
# Epoch 839/900
#
# Epoch 00839: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.4495 - val_accuracy: 0.9264
# Epoch 840/900
#
# Epoch 00840: val_loss did not improve from 0.02253
# 257/257 - 33s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0550 - val_accuracy: 0.9867
# Epoch 841/900
#
# Epoch 00841: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0394 - val_accuracy: 0.9898
# Epoch 842/900
#
# Epoch 00842: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 6.3191e-04 - accuracy: 0.9999 - val_loss: 0.0351 - val_accuracy: 0.9927
# Epoch 843/900
#
# Epoch 00843: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00843: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0519 - val_accuracy: 0.9869
# Epoch 844/900
#
# Epoch 00844: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0875 - val_accuracy: 0.9809
# Epoch 845/900
#
# Epoch 00845: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0542 - val_accuracy: 0.9869
# Epoch 846/900
#
# Epoch 00846: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0377 - val_accuracy: 0.9915
# Epoch 847/900
#
# Epoch 00847: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 8.9240e-04 - accuracy: 0.9999 - val_loss: 0.3411 - val_accuracy: 0.9419
# Epoch 848/900
#
# Epoch 00848: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00848: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.3122 - val_accuracy: 0.9460
# Epoch 849/900
#
# Epoch 00849: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.7379 - val_accuracy: 0.8738
# Epoch 850/900
#
# Epoch 00850: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.0839 - val_accuracy: 0.9826
# Epoch 851/900
#
# Epoch 00851: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0747 - val_accuracy: 0.9828
# Epoch 852/900
#
# Epoch 00852: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 8.7625e-04 - accuracy: 0.9997 - val_loss: 0.0357 - val_accuracy: 0.9918
# Epoch 853/900
#
# Epoch 00853: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00853: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0452 - val_accuracy: 0.9908
# Epoch 854/900
#
# Epoch 00854: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0407 - val_accuracy: 0.9906
# Epoch 855/900
#
# Epoch 00855: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0287 - val_accuracy: 0.9939
# Epoch 856/900
#
# Epoch 00856: val_loss did not improve from 0.02253
# 257/257 - 31s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0338 - val_accuracy: 0.9922
# Epoch 857/900
#
# Epoch 00857: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0424 - val_accuracy: 0.9903
# Epoch 858/900
#
# Epoch 00858: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00858: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0463 - val_accuracy: 0.9893
# Epoch 859/900
#
# Epoch 00859: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0597 - val_accuracy: 0.9857
# Epoch 860/900
#
# Epoch 00860: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 7.2679e-04 - accuracy: 0.9999 - val_loss: 0.0333 - val_accuracy: 0.9915
# Epoch 861/900
#
# Epoch 00861: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0472 - val_accuracy: 0.9891
# Epoch 862/900
#
# Epoch 00862: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0444 - val_accuracy: 0.9891
# Epoch 863/900
#
# Epoch 00863: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00863: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0367 - val_accuracy: 0.9913
# Epoch 864/900
#
# Epoch 00864: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.1026 - val_accuracy: 0.9763
# Epoch 865/900
#
# Epoch 00865: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0406 - val_accuracy: 0.9906
# Epoch 866/900
#
# Epoch 00866: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0736 - val_accuracy: 0.9826
# Epoch 867/900
#
# Epoch 00867: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0505 - val_accuracy: 0.9881
# Epoch 868/900
#
# Epoch 00868: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00868: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.7488 - val_accuracy: 0.8648
# Epoch 869/900
#
# Epoch 00869: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 8.7925e-04 - accuracy: 0.9997 - val_loss: 0.0543 - val_accuracy: 0.9881
# Epoch 870/900
#
# Epoch 00870: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.2948 - val_accuracy: 0.9462
# Epoch 871/900
#
# Epoch 00871: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0442 - val_accuracy: 0.9906
# Epoch 872/900
#
# Epoch 00872: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.2611 - val_accuracy: 0.9503
# Epoch 873/900
#
# Epoch 00873: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00873: val_loss did not improve from 0.02253
# 257/257 - 30s - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1946 - val_accuracy: 0.9622
# Epoch 874/900
#
# Epoch 00874: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 9.7152e-04 - accuracy: 0.9997 - val_loss: 0.0332 - val_accuracy: 0.9922
# Epoch 875/900
#
# Epoch 00875: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0819 - val_accuracy: 0.9838
# Epoch 876/900
#
# Epoch 00876: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0455 - val_accuracy: 0.9893
# Epoch 877/900
#
# Epoch 00877: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0413 - val_accuracy: 0.9896
# Epoch 878/900
#
# Epoch 00878: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00878: val_loss did not improve from 0.02253
# 257/257 - 27s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1032 - val_accuracy: 0.9772
# Epoch 879/900
#
# Epoch 00879: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0437 - val_accuracy: 0.9910
# Epoch 880/900
#
# Epoch 00880: val_loss did not improve from 0.02253
# 257/257 - 27s - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0709 - val_accuracy: 0.9835
# Epoch 881/900
#
# Epoch 00881: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0536 - val_accuracy: 0.9876
# Epoch 882/900
#
# Epoch 00882: val_loss did not improve from 0.02253
# 257/257 - 27s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.8026 - val_accuracy: 0.8588
# Epoch 883/900
#
# Epoch 00883: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00883: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.1703 - val_accuracy: 0.9658
# Epoch 884/900
#
# Epoch 00884: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0905 - val_accuracy: 0.9811
# Epoch 885/900
#
# Epoch 00885: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.2588 - val_accuracy: 0.9523
# Epoch 886/900
#
# Epoch 00886: val_loss did not improve from 0.02253
# 257/257 - 27s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0636 - val_accuracy: 0.9867
# Epoch 887/900
#
# Epoch 00887: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0438 - val_accuracy: 0.9889
# Epoch 888/900
#
# Epoch 00888: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00888: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0908 - val_accuracy: 0.9784
# Epoch 889/900
#
# Epoch 00889: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.1339 - val_accuracy: 0.9688
# Epoch 890/900
#
# Epoch 00890: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0558 - val_accuracy: 0.9859
# Epoch 891/900
#
# Epoch 00891: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 9.9061e-04 - accuracy: 0.9996 - val_loss: 0.0500 - val_accuracy: 0.9872
# Epoch 892/900
#
# Epoch 00892: val_loss did not improve from 0.02253
# 257/257 - 27s - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0377 - val_accuracy: 0.9915
# Epoch 893/900
#
# Epoch 00893: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00893: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0509 - val_accuracy: 0.9876
# Epoch 894/900
#
# Epoch 00894: val_loss did not improve from 0.02253
# 257/257 - 27s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0949 - val_accuracy: 0.9780
# Epoch 895/900
#
# Epoch 00895: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0411 - val_accuracy: 0.9908
# Epoch 896/900
#
# Epoch 00896: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1681 - val_accuracy: 0.9637
# Epoch 897/900
#
# Epoch 00897: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.2668 - val_accuracy: 0.9416
# Epoch 898/900
#
# Epoch 00898: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00898: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0756 - val_accuracy: 0.9845
# Epoch 899/900
#
# Epoch 00899: val_loss did not improve from 0.02253
# 257/257 - 28s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0280 - val_accuracy: 0.9942
# Epoch 900/900
#
# Epoch 00900: val_loss did not improve from 0.02253
# 257/257 - 29s - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0524 - val_accuracy: 0.9862

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 129/129 [==============================] - 2s 15ms/step - loss: 0.0524 - accuracy: 0.9862
# Final Loss: 0.05239863321185112, Final Accuracy: 0.9861918687820435

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 144.41374999999996, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Testing Disease Prediction

# %%
from skimage import io
from keras.preprocessing import image
#path='imbalanced/Scratch/Scratch_400.jpg'
img = image.load_img('../input/plantdisease/PlantVillage/Potato___Early_blight/042135e2-e126-4900-9212-d42d900b8125___RS_Early.B 8791.JPG', grayscale=False, target_size=(64, 64))
show_img=image.load_img('../input/plantdisease/PlantVillage/Potato___Early_blight/042135e2-e126-4900-9212-d42d900b8125___RS_Early.B 8791.JPG', grayscale=False, target_size=(200, 200))
disease_class = ['Pepper__bell___Bacterial_spot','Pepper__bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite','Tomato__Target_Spot','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato__Tomato_mosaic_virus','Tomato_healthy']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
#x = np.array(x, 'float32')
x /= 255

custom = model.predict(x)
print(custom[0])



#x = x.reshape([64, 64]);

#plt.gray()
plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [2.0648220e-05 7.7240333e-02 1.4014610e-03 6.4926482e-08 9.6985670e-05
#  2.8753827e-10 3.6111639e-06 4.6760351e-07 1.1550392e-05 9.2121017e-01
#  1.1517891e-10 2.3624089e-07 9.2484624e-11 1.0890752e-05 3.6359688e-06]
# Prediction: Tomato_Septoria_leaf_spot
